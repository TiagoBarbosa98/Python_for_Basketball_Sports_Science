# %% [markdown]
# # Week 2 – Control Flow & Functions
# Welcome to Week 2! This week we’ll cover conditionals, loops, and functions using basketball examples.

# %% [markdown]
# ## Section A: Control Flow – If/Else

# %%
points = 112

if points > 110:
    print("High scoring game")
elif points >= 90:
    print("Average scoring game")
else:
    print("Low scoring game")

# %% [markdown]
# ## Section B: Loops

# %%
player_points = [25, 18, 12, 15, 10]

total_points = 0
for p in player_points:
    total_points += p

print("Team total points:", total_points)

# %% [markdown]
# ## Section C: Functions

# %%
def effective_fg(FGM, threePM, FGA):
    return (FGM + 0.5 * threePM) / FGA

efg = effective_fg(10, 3, 20)
print("Effective FG%:", round(efg, 3))
# Out:
# Effective FG%: 0.575

# %% [markdown]
# ## Section D: Multi-Stat Function

# %%
def advanced_stats(FGM, FGA, threePM, FTM, FTA, PTS):
    eFG = (FGM + 0.5 * threePM) / FGA
    TS = PTS / (2 * (FGA + 0.44 * FTA))
    return {"eFG%": round(eFG, 3), "TS%": round(TS, 3)}

stats = advanced_stats(10, 20, 3, 6, 8, 29)
print(stats)
# Out:
# {'eFG%': 0.575, 'TS%': 0.616}

# %% [markdown]
# ## Section E: Exercise
# Write a function that:
# 1. Takes a player’s box score line as input.
# 2. Returns at least 3 advanced stats (e.g., eFG%, TS%, USG%).
# 3. Prints them in a readable format.

# %%
def adv_stats(PTS, FGM, threePM, FGA, threePA, FTA):
  eFG = round((FGM + 0.5 * threePM) / FGA, 3)
  TS = round(PTS / (2 * (FGA + 0.44 * FTA)), 3)
  threePAr = round(threePA/FGA*100,3)

  print(f"eFG%: {eFG}\nTS%: {TS}\n3PA%: {threePAr}")

adv_stats(38, 14, 5, 28, 15, 5)
# Out:
# eFG%: 0.589
# TS%: 0.629
# 3PA%: 53.571
