# %% [markdown]
# # Week 1 – Getting Started with Python & Basketball Context
#
# In this notebook, we’ll cover Python basics and use them to calculate basketball pace and efficiency.

# %% [markdown]
# ## Section B: Python Basics

# %%
# Variables
team_name = "Chicago Bulls"
points = 112
possessions = 100

print(team_name, "scored", points, "points on", possessions, "possessions")
# Out:
# Chicago Bulls scored 112 points on 100 possessions

# %% [markdown]
# ## Section C: Data Types

# %%
# Integer
shots = 85

# Float
free_throw_rate = 0.75

# String
player = "Zach LaVine"

# %% [markdown]
# ## Section D: Basketball Application

# %%
# Possessions formula
FGA = 85
FTA = 20
OREB = 10
TO = 15

possessions = FGA + (0.44 * FTA) - OREB + TO
print("Estimated possessions:", possessions)

# Offensive Efficiency
points = 112
off_efficiency = (points / possessions) * 100
print("Offensive Efficiency:", off_efficiency)
# Out:
# Estimated possessions: 98.8
# Offensive Efficiency: 113.36032388663968

# %% [markdown]
# ## Section E: Exercise
# Change the input values to match a real NBA box score and calculate possessions and offensive efficiency.
#
# **Tip:** Use Basketball Reference or NBA.com to find a box score.
